# %% [markdown]
# How to find Missing/Null Values in a dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
# from google.colab import files
# files.upload()  # kaggle.json

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d <dataset-name>
# !unzip *.zip

# %%
dataset = pd.read_csv("../datasets/social_media_engagement1.csv")
dataset.head()
# Out:
#    post_id   platform post_type        post_time  likes  comments  shares  \
# 0        1   Facebook     image  8/17/2023 14:45   2121       474     628
# 1        2   Facebook  carousel   5/14/2023 0:45   3660       432     694
# 2        3  Instagram      poll  2/21/2023 16:15   4955       408     688
# 3        4    Twitter     image  11/16/2023 0:45   1183        90     187
# 4        5    Twitter     video   5/23/2023 0:30   3499       247     286
#
#    post_day sentiment_score
# 0  Thursday        positive
# 1    Sunday         neutral
# 2   Tuesday        negative
# 3  Thursday        negative
# 4   Tuesday        positive

# %%
dataset.shape
# Out:
# (100, 9)

# %%
dataset.isnull().sum()
# Out:
# post_id            0
# platform           0
# post_type          0
# post_time          0
# likes              0
# comments           0
# shares             0
# post_day           0
# sentiment_score    0
# dtype: int64

# %%
dataset.shape[0]
# Out:
# 100

# %%
dataset.isnull().sum()/dataset.shape[0]*100
# Out:
# post_id            0.0
# platform           0.0
# post_type          0.0
# post_time          0.0
# likes              0.0
# comments           0.0
# shares             0.0
# post_day           0.0
# sentiment_score    0.0
# dtype: float64

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1])*100
# Out:
# np.float64(0.0)

# %%
dataset.notnull().sum()
# Out:
# post_id            100
# platform           100
# post_type          100
# post_time          100
# likes              100
# comments           100
# shares             100
# post_day           100
# sentiment_score    100
# dtype: int64

# %%
dataset.notnull().sum()/dataset.shape[0]*100
# Out:
# post_id            100.0
# platform           100.0
# post_type          100.0
# post_time          100.0
# likes              100.0
# comments           100.0
# shares             100.0
# post_day           100.0
# sentiment_score    100.0
# dtype: float64

# %%
dataset.notnull().sum().sum()
# Out:
# np.int64(900)

# %%
dataset.notnull().sum().sum()/(dataset.shape[0]*dataset.shape[1])*100
# Out:
# np.float64(100.0)

# %%
sns.heatmap(dataset.isnull())
plt.show()
