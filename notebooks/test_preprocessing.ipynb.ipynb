# %%
import numpy as np
import pandas as pd
import sklearn

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Sklearn:", sklearn.__version__)
# Out:
# NumPy: 2.4.0
# Pandas: 2.3.3
# Sklearn: 1.8.0

# %%
import pandas as pd
from pathlib import Path
import sys
# add project root (or folder containing `scripts/`) to sys.path so `scripts` can be imported
sys.path.insert(0, str(Path.cwd().parent))

from scripts.preprocessing import (
	handle_missing_values,
	encode_categorical,
	scale_features
)

df = pd.read_csv("../datasets/Loan payments data.csv")

df = handle_missing_values(df)
df = encode_categorical(df)
df = scale_features(df)

df.head()
# Out:
#     Loan_ID  loan_status  Principal     terms  effective_date  due_date  \
# 0  1.534600         0.75   0.493377  0.897891        2.638574 -0.441539
# 1  1.548457         0.75   0.493377  0.897891        2.638574 -0.441539
# 2 -1.700877         0.75   0.493377  0.897891        2.638574 -0.441539
# 3 -1.693949         0.75   0.493377 -0.978972        2.638574  0.811647
# 4 -1.687021         0.75   0.493377  0.897891        3.432369 -0.337107
#
#    paid_off_time  past_due_days       age  education    Gender
# 0      -0.080752            0.0  2.284043  -0.652946  0.426653
# 1      -0.807690            0.0  3.106587  -1.518923 -2.343823
# 2       0.781188            0.0  0.309935  -1.518923 -2.343823
# 3       0.334641            0.0 -0.677119   1.079007  0.426653
# 4       0.459259            0.0 -0.512610   1.079007 -2.343823
