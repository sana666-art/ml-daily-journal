# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from pathlib import Path

fname = "FlavorSense.csv"

# search current directory and parent directories for the file
matches = []
for root in [Path(".")] + list(Path.cwd().parents):
	matches.extend(list(root.rglob(fname)))

if matches:
	path = matches[0]
	print(f"Found file at: {path}")
	dataset = pd.read_csv(path)
	print(dataset.head(10))
else:
	print(f"File '{fname}' not found. Checked current and parent directories.")
# Out:
# Found file at: c:\Users\Noman Traders\Documents\GitHub\ml-daily-journal\datasets\FlavorSense.csv
#     age sleep_cycle exercise_habits climate_zone historical_cuisine_exposure  \
# 0  56.0   Irregular           Heavy    Temperate                         NaN
# 1   NaN   Night Owl           Heavy    Temperate                       Asian
# 2  46.0   Night Owl           Heavy         Cold                       Mixed
# 3  32.0  Early Bird           Heavy         Cold               Mediterranean
# 4  60.0   Night Owl        Moderate          Dry               Mediterranean
# 5  25.0  Early Bird           Heavy         Cold               Mediterranean
# 6  38.0   Irregular           Light    Temperate                       Mixed
# 7  56.0         NaN           Light         Cold                       Mixed
# 8  36.0   Irregular           Light     Tropical               Mediterranean
# 9  40.0  Early Bird           Light    Temperate                       Asian
#
#   preferred_taste
# ...

# %%
dataset.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# dataset.fillna(0).head(100)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1710670 entries, 0 to 1710669
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   TRIP_ID       int64
#  1   CALL_TYPE     object
#  2   ORIGIN_CALL   float64
#  3   ORIGIN_STAND  float64
#  4   TAXI_ID       int64
#  5   TIMESTAMP     int64
#  6   DAY_TYPE      object
#  7   MISSING_DATA  bool
#  8   POLYLINE      object
# dtypes: bool(1), float64(2), int64(3), object(3)
# memory usage: 106.0+ MB

# %%
dataset.fillna(method="bfill") # type: ignore
# Out:
# C:\Users\Noman Traders\AppData\Local\Temp\ipykernel_21860\193979722.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="bfill")
#        age sleep_cycle exercise_habits climate_zone  \
# 0     56.0   Irregular           Heavy    Temperate
# 1     46.0   Night Owl           Heavy    Temperate
# 2     46.0   Night Owl           Heavy         Cold
# 3     32.0  Early Bird           Heavy         Cold
# 4     60.0   Night Owl        Moderate          Dry
# ...    ...         ...             ...          ...
# 9995  55.0   Irregular           Light         Cold
# 9996  51.0  Early Bird           Light          Dry
# 9997  57.0  Early Bird           Light         Cold
# 9998  64.0   Irregular           Light     Tropical
# 9999  32.0  Early Bird           Heavy     Tropical
#
#      historical_cuisine_exposure preferred_taste
# ...

# %%
dataset.bfill()
# Out:
#                      TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 0        1372636858620000589         C      31508.0           7.0  20000589
# 1        1372637303620000596         B      31508.0           7.0  20000596
# 2        1372636951620000320         C      31508.0          13.0  20000320
# 3        1372636854620000520         C      31508.0          13.0  20000520
# 4        1372637091620000337         C      31508.0          13.0  20000337
# ...                      ...       ...          ...           ...       ...
# 1710665  1404171463620000698         C          NaN          12.0  20000698
# 1710666  1404171367620000670         C          NaN          12.0  20000670
# 1710667  1388745716620000264         C          NaN          12.0  20000264
# 1710668  1404141826620000248         B          NaN          12.0  20000248
# 1710669  1404157147620000079         B          NaN          34.0  20000079
#
#           TIMESTAMP DAY_TYPE  MISSING_DATA  \
# ...

# %%
dataset.ffill()
# Out:
#                      TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 0        1372636858620000589         C          NaN           NaN  20000589
# 1        1372637303620000596         B          NaN           7.0  20000596
# 2        1372636951620000320         C          NaN           7.0  20000320
# 3        1372636854620000520         C          NaN           7.0  20000520
# 4        1372637091620000337         C          NaN           7.0  20000337
# ...                      ...       ...          ...           ...       ...
# 1710665  1404171463620000698         C      52688.0           9.0  20000698
# 1710666  1404171367620000670         C      52688.0           9.0  20000670
# 1710667  1388745716620000264         C      52688.0           9.0  20000264
# 1710668  1404141826620000248         B      52688.0          12.0  20000248
# 1710669  1404157147620000079         B      52688.0          34.0  20000079
#
#           TIMESTAMP DAY_TYPE  MISSING_DATA  \
# ...

# %%
for i in dataset.select_dtypes(include="object").columns:
    dataset[i].fillna(dataset[i].mode()[0])
