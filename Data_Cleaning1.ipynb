# %% [raw]
# Methods 1 and 2: (Using Dropping Method)
# Data Cleaning: to overcome the missing/null value, we deleted the rows and columns of that particular data.
# (not a good approach)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r'FlavorSense.csv')
dataset.head(10)
# Out:
#     age sleep_cycle exercise_habits climate_zone historical_cuisine_exposure  \
# 0  56.0   Irregular           Heavy    Temperate                         NaN
# 1   NaN   Night Owl           Heavy    Temperate                       Asian
# 2  46.0   Night Owl           Heavy         Cold                       Mixed
# 3  32.0  Early Bird           Heavy         Cold               Mediterranean
# 4  60.0   Night Owl        Moderate          Dry               Mediterranean
# 5  25.0  Early Bird           Heavy         Cold               Mediterranean
# 6  38.0   Irregular           Light    Temperate                       Mixed
# 7  56.0         NaN           Light         Cold                       Mixed
# 8  36.0   Irregular           Light     Tropical               Mediterranean
# 9  40.0  Early Bird           Light    Temperate                       Asian
#
#   preferred_taste
# 0           Salty
# 1           Sweet
# 2            Sour
# 3           Salty
# 4            Sour
# ...

# %%
dataset.shape
# Out:
# (10000, 6)

# %%
dataset.shape
# Out:
# (7580, 5)

# %%
((10000-7580)/10000)*100
# Out:
# 24.2

# %%
dataset.isnull().sum()
# Out:
# age                            968
# sleep_cycle                    684
# exercise_habits                804
# climate_zone                   533
# historical_cuisine_exposure    654
# preferred_taste                  0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.isnull().sum()/dataset.shape[0]
# Out:
# age                            0.0968
# sleep_cycle                    0.0684
# exercise_habits                0.0804
# climate_zone                   0.0533
# historical_cuisine_exposure    0.0654
# preferred_taste                0.0000
# dtype: float64

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(3643)

# %%
dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1])*100
# Out:
# np.float64(6.071666666666667)

# %% [raw]
# Method: 01
# if data is missing more then 50%, then we deleted that particular column.
#
# Method: 02
# if data is missing more then 50%, we deleted that specific row which contains a null value
#
# we also full that particular column, that's missing, when data is more imp

# %%
dataset.drop(columns=["age"],inplace=True)

# %%
dataset.dropna(inplace=True)

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %% [raw]
# by deleting age column, I almost lost 53% of my existing data, maybe, you lose important data which can be usefull  in ML. So beware of what data you are using and keep the knowlodge of that dataset.
