# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r'C:\Users\Tesla Laptops\Downloads\archive (1)/train.csv')
dataset.head(10)
# Out:
#                TRIP_ID CALL_TYPE  ORIGIN_CALL  ORIGIN_STAND   TAXI_ID  \
# 0  1372636858620000589         C          NaN           NaN  20000589
# 1  1372637303620000596         B          NaN           7.0  20000596
# 2  1372636951620000320         C          NaN           NaN  20000320
# 3  1372636854620000520         C          NaN           NaN  20000520
# 4  1372637091620000337         C          NaN           NaN  20000337
# 5  1372636965620000231         C          NaN           NaN  20000231
# 6  1372637210620000456         C          NaN           NaN  20000456
# 7  1372637299620000011         C          NaN           NaN  20000011
# 8  1372637274620000403         C          NaN           NaN  20000403
# 9  1372637905620000320         C          NaN           NaN  20000320
#
#     TIMESTAMP DAY_TYPE  MISSING_DATA  \
# 0  1372636858        A         False
# 1  1372637303        A         False
# 2  1372636951        A         False
# 3  1372636854        A         False
# ...

# %%
dataset.shape
# Out:
# (1710670, 9)

# %%
dataset.shape
# Out:
# (1710670, 8)

# %%
dataset.shape
# Out:
# (806579, 8)

# %%
((1710670-806579)/1710670)*100
# Out:
# 52.850111359876536

# %% [raw]
# dataset.isnull().sum()

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.isnull().sum()/dataset.shape[0]
# Out:
# TRIP_ID         0.000000
# CALL_TYPE       0.000000
# ORIGIN_CALL     0.786768
# ORIGIN_STAND    0.528501
# TAXI_ID         0.000000
# TIMESTAMP       0.000000
# DAY_TYPE        0.000000
# MISSING_DATA    0.000000
# POLYLINE        0.000000
# dtype: float64

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(2249991)

# %%
dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1])*100
# Out:
# np.float64(14.61409856956631)

# %% [raw]
# Method: 01
# if data is missing more then 50%, then we deleted that particular column.
#
# Method: 02
# if data is missing more then 50%, we deleted that specific row which contains a null value
#
# we also full that particular column, that's missing, when data is more imp

# %%
dataset.drop(columns=["ORIGIN_CALL"],inplace=True)

# %%
dataset.dropna(inplace=True)

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %% [raw]
# by deleting ORIGIN_CALL column, I almost lost 53% of my existing data, maybe, you lose important data which can be usefull  in ML. So beware of what data you are using and keep the knowlodge of that dataset.
